# %% [markdown]
# <a href="https://colab.research.google.com/github/Pabloskking/Probabilidad-y-Estad-stica/blob/main/Unidad4/PRO_U4_Practica_1_Distribuci%C3%B3n_Normal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadística
#
# ##Unidad 4. Distribución de probabilidad
# Alumno: Juan Pablo Soriano Gonzalez
# Facilitador: José Gabriel Rodríguez Rivas

# %% [markdown]
# #Practica 1: Distribución Normal
# Aplica para variables aleatorias continuas (número infinito de valores).

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Generar datos para la distribución normal

media = 70 # Media
desv_std = 4 # Desviación estándar
num_datos = 500

# Generamos los datos de manera aleatoria y los ponemos en una lista (array)
datos = np.random.normal(media, desv_std, num_datos)
datos[0:50] # Mostrar los primeros 50
# Out:
# array([65.18367259, 67.45122631, 71.36517774, 74.41382328, 73.8969499 ,
#        69.93352684, 72.58145036, 59.46524613, 72.9209036 , 71.59847698,
#        70.43500843, 74.87518359, 69.62411119, 70.8747592 , 70.99122385,
#        74.58125448, 68.87844063, 73.11460929, 63.24955898, 69.16281655,
#        63.17559982, 71.55311221, 71.52188592, 60.72513351, 67.73103258,
#        75.4491688 , 69.48318281, 69.60655839, 61.61750415, 63.74765455,
#        67.56946876, 67.03997845, 72.61958111, 67.26916587, 68.51244217,
#        58.58739466, 72.34802877, 63.09784039, 64.48431413, 75.117524  ,
#        67.36367541, 79.92468467, 72.01921884, 69.57792573, 66.04869484,
#        70.34042511, 76.73199597, 74.57036709, 72.35329913, 70.73071736])

# %%
# Crear un rango de valores para crear una densidad
x = np.linspace(media - 3 * desv_std, media + 3 * desv_std, num_datos)

# Calcular la PDF de la distribución normal
pdf = 1 / (desv_std * np.sqrt(2 * np.pi)) * np.exp(-(x - media)**2 / (2 * desv_std **2))

# %%
pdf.size, num_datos
# Out:
# (500, 500)

# %%
# Graficar histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, color='b') # Histograma de los datos
plt.title('Distribución Normal ')
plt.xlabel('Peso en Kg de los estudiantes')
plt.grid(True)
plt.show()

# %%
# Visualizar la PDF
plt.figure(figsize=(6, 4))
plt.plot(x, pdf, label='Normal:(media:{}; ds:{})'.format(np.round(media,2), np.round(desv_std, 2)))
plt.title('Función de Densidad de Probabilidad (PDF) - Distrubución Normal')
plt.xlabel('Peso en Kg de los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Graficar histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b') # Histograma de los datos
plt.plot( x, pdf, 'k', linewidth=2, )
plt.title('Distribución Normal ')
plt.xlabel('Peso en Kg de los estudiantes')
plt.grid(True)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## **Ejercicio 2**

# %%
plt.figure(figsize=(6, 4))

# Parámetros de la distribución normal
media = 70 # Media
desv_std = 4 # Desviación estándar
total_estudiantes = 500

# VARIABLE para cálculo de la probabilidad de que un estudiantes que pese menos de 75 kg
peso_limite = 75

# Primero necesitamos calcular la probabilidad de que un estudiante pese menos
# de 75 kg utilizando la función de distribución acomulativa (CDF) de la distribucipon normal
prob_menos_75kg = norm.cdf(peso_limite, media, desv_std)

# %%
# Cálculo del número de estudiantes que pesan menos de 75 kg
estudiantes_menos_75kg = prob_menos_75kg * total_estudiantes

print("Probabilidad de que un estudiante pese menos de 75 kg:", prob_menos_75kg)
print("Número de estudiantes que pesan menos de 75 kg:", estudiantes_menos_75kg)

# Graficar la distribución normal
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 1000)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.xlabel('Peso en Kg de los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.title('Probabilidad de que un estudiante pese menos de 75 kg. \n $\mu=70$, $\sigma=4$, x=500')
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un estudiante pese menos de 75 kg: 0.8943502263331446
# Número de estudiantes que pesan menos de 75 kg: 447.1751131665723

# %% [markdown]
# ## **Cuantos estudiantes pesan menos de 62 kg.**

# %%
plt.figure(figsize=(6, 4))

# Parámetros de la distribución normal
media = 70 #Media
desv_std = 4 #Desviación estándar
total_estudiantes = 500

# VARIABLE para cálculo de la probabilidad de que un estudiante pese menos de 75 kg
peso_limite = 62

# Primero necesitamos calcular la probabilidad de que un estudiante pese menos
# de 75 kg utilizando la función de distribución acomulativa (CDF) de la distribucipon normal
prob_menos_62kg = norm.cdf(peso_limite, media, desv_std)

# Cálculo del número de estudiantes que pesan menos de 75 kg
estudiantes_menos_62kg = prob_menos_62kg * total_estudiantes

print("Probabilidad de que un estudiante pese menos de 62 kg:", prob_menos_62kg)
print("Número de estudiantes que pesan menos de 75 kg:", estudiantes_menos_62kg)
# Out:
# Probabilidad de que un estudiante pese menos de 62 kg: 0.022750131948179195
# Número de estudiantes que pesan menos de 75 kg: 11.375065974089598

# %%
# Calculaar la distribucion normal
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

# Graficar la distribución normal
plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.xlabel('Peso en Kg de los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.title('Probabilidad de que un estudiante pese menos de 62 kg. \n $\mu=70$, $\sigma=4$, x=500')
plt.grid(True)
plt.show()

# %% [markdown]
# ## **Cuantos estudiantes pesan mas de 79 kg.**

# %%
plt.figure(figsize=(6, 4))

# Parámetros de la distrubución normal
media = 70 # Media
desv_std = 4 # Desviación estándar
peso_limite = 79 # Peso límite
total_estudiantes = 500

# Calculamos la probabilidad de que un estudiante pese menos o igual a 79 kg
prob_menos_79kg = norm.cdf(peso_limite, media, desv_std)

# La probabilidad de que un estudiante pese más de 79 kg es complementaria
prob_mas_79kg = 1 - prob_menos_79kg

# Cálculamos el número aproximado de estudiantes que pesan más de 79 kg
estudiantes_mas_79kg = prob_mas_79kg * total_estudiantes

print("Probabilidad de que un estudiante pese menos de 79 kg:", prob_mas_79kg)
print("Número aproximado de estudiantes que pesan más de 79 kg:", estudiantes_mas_79kg)
# Out:
# Probabilidad de que un estudiante pese menos de 79 kg: 0.012224472655044671
# Número aproximado de estudiantes que pesan más de 79 kg: 6.112236327522336

# %%
# Calcular la función de densidad de probabilidad de la distribucion normal
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x >= peso_limite), color='skyblue', alpha=0.5)
plt.xlabel('Peso en Kg de los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.title('Probabilidad de que un estudiante pese más de 79 kg. \n $\mu=70$, $\sigma=4$, x=500')
plt.grid(True)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # **La probabilidad de estudiantes que pesan más de 68 y menos de 72 kg.**

# %% [markdown]
# ### **Estudiantes que pesan más de 68 kg.**

# %%
plt.figure(figsize=(6, 4))

# Parámetros de la distrubución normal
media = 70 # Media
desv_std = 4 # Desviación estándar
peso_limite = 68 # Peso límite

total_estudiantes = 500

# Calculamos la probabilidad de que un estudiante pese menos o igual a 79 kg
prob_menos_68kg = norm.cdf(peso_limite, media, desv_std)

# La probabilidad de que un estudiante pese más de 79 kg es complementaria
prob_mas_68kg = 1 - prob_menos_68kg

# Cálculamos el número aproximado de estudiantes que pesan más de 79 kg
estudiantes_mas_68kg = prob_mas_68kg * total_estudiantes

print("Probabilidad de que un estudiante pese menos de 68 kg:", prob_mas_68kg)
print("Número aproximado de estudiantes que pesan más de 68 kg:", estudiantes_mas_68kg)
# Out:
# Probabilidad de que un estudiante pese menos de 68 kg: 0.6914624612740131
# Número aproximado de estudiantes que pesan más de 68 kg: 345.73123063700655

# %%
# Calcular la función de densidad de probabilidad de la distribucion normal
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x >= peso_limite), color='skyblue', alpha=0.5)
plt.xlabel('Peso en Kg de los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.title('Probabilidad de que un estudiante pese más de 68 kg. \n $\mu=70$, $\sigma=4$, x=500')
plt.grid(True)
plt.show()

# %% [markdown]
# ### **Estudiantes que pesan menos de 72 kg.**

# %%
plt.figure(figsize=(6, 4))

# Parámetros de la distribución normal
media = 70 # Media
desv_std = 4 # Desviación estándar
total_estudiantes = 500
peso_minimo = 68 # Peso Minimo
peso_limite = 72 # Peso Límite

# Primero necesitamos calcular la probabilidad de que un estudiante pese menos
# de 75 kg utilizando la función de distribución acomulativa (CDF) de la distribucipon normal
prob_menos_72kg = norm.cdf(peso_limite, media, desv_std)

# %%
# Cálculo del número de estudiantes que pesan menos de 72 kg
estudiantes_menos_72kg = prob_menos_72kg * total_estudiantes

print("Probabilidad de que un estudiante pese menos de 72 kg:", prob_menos_72kg)
print("Número de estudiantes que pesan menos de 72 kg:", estudiantes_menos_72kg)

# Graficar la distribución normal
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 1000)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.xlabel('Peso en Kg de los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.title('Probabilidad de que un estudiante pese menos de 72 kg. \n $\mu=70$, $\sigma=4$, x=500')
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un estudiante pese menos de 72 kg: 0.6914624612740131
# Número de estudiantes que pesan menos de 72 kg: 345.73123063700655

# %% [markdown]
# ### **Estudiantes que pesan más de 68 kg y menos de 72 kg.**

# %%
# Parámetros
media = 70
desv_std = 4
total_estudiantes = 500

# Límites de interés
peso_min = 68
peso_max = 72

# Dominio para la gráfica
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 1000)
y = norm.pdf(x, media, desv_std)

# Calcular la probabilidad de estar entre 68 y 72 kg
prob_entre = norm.cdf(peso_max, media, desv_std) - norm.cdf(peso_min, media, desv_std)
estudiantes_entre = prob_entre * total_estudiantes

# Graficar la distribución y el área de interés
plt.figure(figsize=(6, 4))
plt.plot(x, y, 'k', linewidth=2, label='Distribución Normal')
plt.fill_between(x, y, where=(x >= peso_min) & (x <= peso_max), color='skyblue', alpha=0.5,
                 label='Entre 68 y 72 kg')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de Probabilidad')
plt.title('Distribución Normal: Estudiantes entre 68 y 72 kg')
plt.legend()
plt.grid(True)
plt.show()

print("Probabilidad entre 68 y 72 kg:", prob_entre)
print("Número aproximado de estudiantes entre 68 y 72 kg:", estudiantes_entre)
# Out:
# Probabilidad entre 68 y 72 kg: 0.38292492254802624
# Número aproximado de estudiantes entre 68 y 72 kg: 191.46246127401312
