# %% [markdown]
# <a href="https://colab.research.google.com/github/Pabloskking/Probabilidad-y-Estad-stica/blob/main/Unidad1/Pr%C3%A1ctica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadística
# ![Tecno logo.png](data:image/png;base64,...)
#
#
# ## **Unidad 1**
#
# *   **Práctica #3**
#
# **Grupo:** 2Y
#
# **Alumno:** Juan Pablo Soriano González
#
# **Docente:** Dr. José Gabriel Rodríguez Rivas

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
    numero_aleatorio = round( random.uniform(50,100),2 )
    fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [81.55, 81.92, 69.63, 91.1, 88.05, 54.01, 89.9, 99.21, 59.16, 54.8, 82.96, 77.65, 65.09, 55.94, 98.75, 78.97, 95.58, 78.77, 80.0, 82.17, 60.21, 94.38, 97.18, 94.54, 79.07, 59.17, 83.34, 94.64, 81.21, 98.96, 83.62, 91.19, 79.11, 76.25, 81.78, 60.98, 99.35, 88.47, 61.19, 84.21, 58.11, 97.26, 70.05, 60.03, 64.57, 83.47, 84.37, 62.16, 87.16, 73.21, 68.34, 59.14, 56.0, 74.22, 90.66, 94.88, 64.2, 72.28, 98.03, 93.98, 87.15, 91.63, 65.61, 77.97, 70.41, 94.19, 55.91, 77.16, 63.2, 88.12, 88.92, 66.95, 86.94, 59.9, 57.11, 96.89, 72.87, 80.46, 64.52, 54.83, 64.17, 83.2, 70.28, 55.31, 65.46, 94.83, 71.66, 60.67, 85.59, 56.48, 54.85, 92.71, 99.04, 91.14, 56.52, 88.95, 70.0, 58.2, 55.25, 55.3]

# %%
fabrica2 = []
for i in range(100):
    numero_aleatorio2 = round( random.uniform(50,100),2 )
    fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [53.86, 76.0, 66.51, 79.07, 83.74, 88.6, 67.5, 75.92, 97.88, 58.01, 83.93, 80.99, 63.16, 53.7, 61.62, 79.1, 58.89, 78.58, 73.53, 77.07, 51.75, 72.5, 50.56, 81.12, 91.26, 94.47, 69.39, 52.61, 71.5, 77.93, 58.57, 80.99, 66.4, 69.55, 80.71, 63.11, 68.35, 79.1, 90.09, 93.13, 59.18, 92.89, 72.21, 92.95, 83.01, 89.47, 58.62, 60.21, 70.92, 94.8, 87.2, 76.25, 50.63, 90.32, 54.09, 88.17, 77.46, 53.73, 67.23, 68.99, 91.82, 65.41, 95.22, 87.89, 73.12, 80.68, 60.99, 51.74, 68.55, 94.97, 71.74, 69.7, 84.96, 94.97, 77.32, 55.49, 71.43, 59.76, 89.64, 58.12, 85.19, 78.98, 63.11, 58.36, 82.94, 69.13, 66.15, 84.59, 69.84, 91.02, 76.31, 70.46, 64.83, 72.57, 50.84, 85.84, 63.14, 69.43, 77.83, 53.21]

# %% [markdown]
# # Maximo, mínimo y rango

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print( "Estadística descriptiva de la Fabrica 1 \n", "Media =", media1,
      "\n Mediana =", mediana1, "\n Moda =", moda1, "\n Maximo =", maximo1,
      "\n Minimo =", minimo1, "\n Rango =", rango1)
# Out:
# Estadística descriptiva de la Fabrica 1
#  Media = 76.5653
#  Mediana = 78.87
#  Moda = 81.55
#  Maximo = 99.35
#  Minimo = 54.01
#  Rango = 45.339999999999996

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print( "Estadística descriptiva de la Fabrica 2 \n", "Media =", media2,
      "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo =", maximo2,
      "\n Minimo =", minimo2, "\n Rango=", rango2)
# Out:
# Estadística descriptiva de la Fabrica 2
#  Media = 73.4637
#  Mediana = 72.535
#  Moda = 80.99
#  Maximo = 97.88
#  Minimo = 50.56
#  Rango= 47.31999999999999

# %% [markdown]
# # Dispersión de los datos

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 14.465108661740485

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 13.032905802102025

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline (mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estándar={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle='dashed',
            linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline (mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2, label=f'Desv. Estándar={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media1 + desviacion_estandar_fabrica2, color='black', linestyle='dashed',
            linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# # Densidad

# %%
import seaborn as sns

# %%
# La densidad gráfica es una forma de visualizar la distribución de datos en
# un intervalo o período de tiempo continuo.
# Se basa en un histograma que usa el suavizado de kernel para trazar valores,
# lo que permite obtener distribuciones más suaves al reducir el ruido.
# Una curva de densidad muestra la ubicación de la media y la mediana de una distribución.

sns.histplot(x = fabrica1, kde = True, kde_kws = {'bw_adjust': 0.5}, bins = 10 )
# Out:
# <Axes: ylabel='Count'>
