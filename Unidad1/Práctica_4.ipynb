# %% [markdown]
# <a href="https://colab.research.google.com/github/Pabloskking/Probabilidad-y-Estad-stica/blob/main/Unidad1/Pr%C3%A1ctica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadística
#
# ![Tecno logo.png](data:image/png;base64,...)
#
# ## **Unidad 1**
#
# *   **Práctica #4** *Tabla de frecuencias y regla de Sturges.*
#
# **Grupo:** 2Y
#
# **Alumno:** Juan Pablo Soriano González
#
# **Docente:** Dr. José Gabriel Rodríguez Rivas

# %% [markdown]
# ## Tablas de frecuencias

# %%
import random

# %%
# basado en el LIBRO estadística para administración pagina 12
# creamos una lista vacia que representa la edad de 100 personas

edades= []

# Hacemos un ciclo para generar 100 números aleatorios que representan la edad de las personas
for i in range(100):
    # generamos un número aleatorio con la funcion randint y lo guardamos en la variable
    # numero_aleatorio
    numero_aleatorio = random.randint( 18, 70)
    # Agregamos el número aleatorio a la lista de valores
    edades.append(numero_aleatorio)

print(edades)
# Out:
# [35, 44, 20, 21, 38, 54, 66, 21, 56, 52, 20, 32, 30, 29, 44, 59, 67, 48, 43, 54, 37, 63, 43, 59, 28, 23, 28, 46, 46, 53, 27, 22, 37, 55, 64, 66, 32, 23, 53, 22, 24, 59, 19, 25, 55, 45, 42, 36, 40, 37, 46, 33, 69, 35, 56, 45, 24, 61, 18, 40, 23, 66, 36, 55, 29, 58, 34, 22, 46, 56, 24, 43, 46, 56, 39, 19, 38, 36, 32, 24, 18, 66, 45, 36, 36, 54, 46, 65, 22, 53, 25, 45, 61, 59, 28, 68, 20, 55, 27, 49]

# %%
import pandas as pd

# %%
# Crear un DataFrame de pandas con los números aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    35
# 1    44
# 2    20
# 3    21
# 4    38

# %%
# Calcular la tabla de distribución de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribuciones de frecuencias
print("Tabla de Distribuciones de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribuciones de Frecuencias:
#     Edad  Frecuencia
# 21    18           2
# 20    19           2
# 15    20           3
# 25    21           2
# 6     22           4
# 14    23           3
# 4     24           4
# 19    25           2
# 23    27           2
# 13    28           3
# 24    29           2
# 36    30           1
# 9     32           3
# 34    33           1
# 32    34           1
# 22    35           2
# 1     36           5
# 12    37           3
# 26    38           2
# 31    39           1
# 17    40           2
# 37    42           1
# 11    43           3
# 27    44           2
# 2     45           4
# 0     46           6
# 39    48           1
# 42    49           1
# 35    52           1
# 16    53           3
# 10    54           3
# 7     55           4
# 3     56           4
# 33    58           1
# 5     59           4
# 18    61           2
# 40    63           1
# 41    64           1
# 30    65           1
# 8     66           4
# 38    67           1
# 29    68           1
# 28    69           1

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 21    18           2           0.02
# 20    19           2           0.02
# 15    20           3           0.03
# 25    21           2           0.02
# 6     22           4           0.04
# 14    23           3           0.03
# 4     24           4           0.04
# 19    25           2           0.02
# 23    27           2           0.02
# 13    28           3           0.03
# 24    29           2           0.02
# 36    30           1           0.01
# 9     32           3           0.03
# 34    33           1           0.01
# 32    34           1           0.01
# 22    35           2           0.02
# 1     36           5           0.05
# 12    37           3           0.03
# 26    38           2           0.02
# 31    39           1           0.01
# 17    40           2           0.02
# 37    42           1           0.01
# 11    43           3           0.03
# 27    44           2           0.02
# 2     45           4           0.04
# 0     46           6           0.06
# 39    48           1           0.01
# 42    49           1           0.01
# 35    52           1           0.01
# 16    53           3           0.03
# 10    54           3           0.03
# 7     55           4           0.04
# 3     56           4           0.04
# 33    58           1           0.01
# 5     59           4           0.04
# 18    61           2           0.02
# 40    63           1           0.01
# 41    64           1           0.01
# 30    65           1           0.01
# 8     66           4           0.04
# 38    67           1           0.01
# 29    68           1           0.01
# 28    69           1           0.01

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 21    18           2           0.02              2.0
# 20    19           2           0.02              2.0
# 15    20           3           0.03              3.0
# 25    21           2           0.02              2.0
# 6     22           4           0.04              4.0
# 14    23           3           0.03              3.0
# 4     24           4           0.04              4.0
# 19    25           2           0.02              2.0
# 23    27           2           0.02              2.0
# 13    28           3           0.03              3.0
# 24    29           2           0.02              2.0
# 36    30           1           0.01              1.0
# 9     32           3           0.03              3.0
# 34    33           1           0.01              1.0
# 32    34           1           0.01              1.0
# 22    35           2           0.02              2.0
# 1     36           5           0.05              5.0
# 12    37           3           0.03              3.0
# 26    38           2           0.02              2.0
# 31    39           1           0.01              1.0
# 17    40           2           0.02              2.0
# 37    42           1           0.01              1.0
# 11    43           3           0.03              3.0
# 27    44           2           0.02              2.0
# 2     45           4           0.04              4.0
# 0     46           6           0.06              6.0
# 39    48           1           0.01              1.0
# 42    49           1           0.01              1.0
# 35    52           1           0.01              1.0
# 16    53           3           0.03              3.0
# 10    54           3           0.03              3.0
# 7     55           4           0.04              4.0
# 3     56           4           0.04              4.0
# 33    58           1           0.01              1.0
# 5     59           4           0.04              4.0
# 18    61           2           0.02              2.0
# 40    63           1           0.01              1.0
# 41    64           1           0.01              1.0
# 30    65           1           0.01              1.0
# 8     66           4           0.04              4.0
# 38    67           1           0.01              1.0
# 29    68           1           0.01              1.0
# 28    69           1           0.01              1.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 21    18           2           0.02              2.0               2
# 20    19           2           0.02              2.0               4
# 15    20           3           0.03              3.0               7
# 25    21           2           0.02              2.0               9
# 6     22           4           0.04              4.0              13
# 14    23           3           0.03              3.0              16
# 4     24           4           0.04              4.0              20
# 19    25           2           0.02              2.0              22
# 23    27           2           0.02              2.0              24
# 13    28           3           0.03              3.0              27
# 24    29           2           0.02              2.0              29
# 36    30           1           0.01              1.0              30
# 9     32           3           0.03              3.0              33
# 34    33           1           0.01              1.0              34
# 32    34           1           0.01              1.0              35
# 22    35           2           0.02              2.0              37
# 1     36           5           0.05              5.0              42
# 12    37           3           0.03              3.0              45
# 26    38           2           0.02              2.0              47
# 31    39           1           0.01              1.0              48
# 17    40           2           0.02              2.0              50
# 37    42           1           0.01              1.0              51
# 11    43           3           0.03              3.0              54
# 27    44           2           0.02              2.0              56
# 2     45           4           0.04              4.0              60
# 0     46           6           0.06              6.0              66
# 39    48           1           0.01              1.0              67
# 42    49           1           0.01              1.0              68
# 35    52           1           0.01              1.0              69
# 16    53           3           0.03              3.0              72
# 10    54           3           0.03              3.0              75
# 7     55           4           0.04              4.0              79
# 3     56           4           0.04              4.0              83
# 33    58           1           0.01              1.0              84
# 5     59           4           0.04              4.0              88
# 18    61           2           0.02              2.0              90
# 40    63           1           0.01              1.0              91
# 41    64           1           0.01              1.0              92
# 30    65           1           0.01              1.0              93
# 8     66           4           0.04              4.0              97
# 38    67           1           0.01              1.0              98
# 29    68           1           0.01              1.0              99
# 28    69           1           0.01              1.0             100

# %% [markdown]
# ---

# %% [markdown]
# ## Regla de sturges
# 1. Es una regla que sirve para calcular el número de clases o intervalos idóneos en los que que se debe dividir un conjunto de datos.
# 2.Establece que **el número de clases es igual a uno más el logaritmo en base dos del número total de datos.**
#
# ** * C= 1 + log²(N)* **
#
# Donde *N* es el tamaño de la muestra.

# %%
import math

# %%
# Volvemos a usar la lista de edades
print (edades)
# Out:
# [35, 44, 20, 21, 38, 54, 66, 21, 56, 52, 20, 32, 30, 29, 44, 59, 67, 48, 43, 54, 37, 63, 43, 59, 28, 23, 28, 46, 46, 53, 27, 22, 37, 55, 64, 66, 32, 23, 53, 22, 24, 59, 19, 25, 55, 45, 42, 36, 40, 37, 46, 33, 69, 35, 56, 45, 24, 61, 18, 40, 23, 66, 36, 55, 29, 58, 34, 22, 46, 56, 24, 43, 46, 56, 39, 19, 38, 36, 32, 24, 18, 66, 45, 36, 36, 54, 46, 65, 22, 53, 25, 45, 61, 59, 28, 68, 20, 55, 27, 49]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     35
# 1     44
# 2     20
# 3     21
# 4     38
# ..   ...
# 95    68
# 96    20
# 97    55
# 98    27
# 99    49
#
# [100 rows x 1 columns]

# %%
# Calcular el número de intervalos utilizando la regla de Sturges
n = len(edades)
k = int( 1 + math.log2(100))
print("Valor de n = ", n , " \nNúmero de intervalos =", k)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
# Crear la tabla de frecuencias

tabla_frecuencia = pd.cut( df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (17.948, 25.286]    22
# 1  (39.857, 47.143]    18
# 2  (32.571, 39.857]    15
# 3  (54.429, 61.714]    15
# 4  (25.286, 32.571]    11
# 5    (61.714, 69.0]    10
# 6  (47.143, 54.429]     9

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (17.948, 25.286]    22
# 4  (25.286, 32.571]    11
# 2  (32.571, 39.857]    15
# 1  (39.857, 47.143]    18
# 6  (47.143, 54.429]     9
# 3  (54.429, 61.714]    15
# 5    (61.714, 69.0]    10

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 0  (17.948, 25.286]    22      0.22       22.0       22         0.22
# 4  (25.286, 32.571]    11      0.11       11.0       33         0.33
# 2  (32.571, 39.857]    15      0.15       15.0       48         0.48
# 1  (39.857, 47.143]    18      0.18       18.0       66         0.66
# 6  (47.143, 54.429]     9      0.09        9.0       75         0.75
# 3  (54.429, 61.714]    15      0.15       15.0       90         0.90
# 5    (61.714, 69.0]    10      0.10       10.0      100         1.00
#
#    Frec Porc Ac
# 0          22.0
# 4          33.0
# 2          48.0
# 1          66.0
# 6          75.0
# 3          90.0
# 5         100.0
