# %% [markdown]
# <a href="https://colab.research.google.com/github/Pabloskking/Probabilidad-y-Estad-stica/blob/main/Unidad1/Pr%C3%A1ctica_4y5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y Estadística
#
# ![Tecno logo.png](data:image/png;base64,...)
#
# ## **Unidad 1**
#
# *   **Práctica #4** *Tabla de frecuencias y regla de Sturges.*
#
# *   **Práctica #5** *Diagramas de cajas y bigotes.*
#
#
# **Grupo:** 2Y
#
# **Alumno:** Juan Pablo Soriano González
#
# **Docente:** Dr. José Gabriel Rodríguez Rivas

# %% [markdown]
# ## Tablas de frecuencias

# %%
import random

# %%
# basado en el LIBRO estadística para administración pagina 12
# creamos una lista vacia que representa la edad de 100 personas

edades= []

# Hacemos un ciclo para generar 100 números aleatorios que representan la edad de las personas
for i in range(100):
    # generamos un número aleatorio con la funcion randint y lo guardamos en la variable
    # numero_aleatorio
    numero_aleatorio = random.randint( 18, 70)
    # Agregamos el número aleatorio a la lista de valores
    edades.append(numero_aleatorio)

print(edades)
# Out:
# [59, 24, 67, 67, 42, 45, 41, 34, 64, 33, 35, 64, 62, 52, 20, 27, 40, 46, 64, 63, 65, 50, 35, 32, 36, 57, 43, 18, 38, 33, 18, 49, 31, 54, 45, 38, 40, 59, 43, 44, 51, 64, 52, 30, 50, 34, 28, 68, 26, 58, 68, 34, 48, 43, 19, 53, 19, 27, 35, 67, 48, 34, 44, 44, 25, 24, 45, 60, 21, 49, 37, 22, 23, 61, 58, 65, 29, 67, 68, 53, 66, 59, 66, 32, 38, 36, 19, 21, 38, 48, 55, 64, 35, 60, 44, 52, 57, 46, 20, 64]

# %%
import pandas as pd

# %%
# Crear un DataFrame de pandas con los números aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    59
# 1    24
# 2    67
# 3    67
# 4    42

# %%
# Calcular la tabla de distribución de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribuciones de frecuencias
print("Tabla de Distribuciones de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribuciones de Frecuencias:
#     Edad  Frecuencia
# 14    18           2
# 7     19           3
# 13    20           2
# 17    21           2
# 34    22           1
# 33    23           1
# 22    24           2
# 36    25           1
# 39    26           1
# 18    27           2
# 41    28           1
# 31    29           1
# 37    30           1
# 44    31           1
# 25    32           2
# 19    33           2
# 3     34           4
# 5     35           4
# 24    36           2
# 35    37           1
# 1     38           4
# 30    40           2
# 40    41           1
# 38    42           1
# 10    43           3
# 4     44           4
# 12    45           3
# 29    46           2
# 8     48           3
# 20    49           2
# 26    50           2
# 42    51           1
# 6     52           3
# 21    53           2
# 43    54           1
# 47    55           1
# 23    57           2
# 15    58           2
# 11    59           3
# 16    60           2
# 32    61           1
# 45    62           1
# 46    63           1
# 0     64           6
# 27    65           2
# 28    66           2
# 2     67           4
# 9     68           3

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 14    18           2           0.02
# 7     19           3           0.03
# 13    20           2           0.02
# 17    21           2           0.02
# 34    22           1           0.01
# 33    23           1           0.01
# 22    24           2           0.02
# 36    25           1           0.01
# 39    26           1           0.01
# 18    27           2           0.02
# 41    28           1           0.01
# 31    29           1           0.01
# 37    30           1           0.01
# 44    31           1           0.01
# 25    32           2           0.02
# 19    33           2           0.02
# 3     34           4           0.04
# 5     35           4           0.04
# 24    36           2           0.02
# 35    37           1           0.01
# 1     38           4           0.04
# 30    40           2           0.02
# 40    41           1           0.01
# 38    42           1           0.01
# 10    43           3           0.03
# 4     44           4           0.04
# 12    45           3           0.03
# 29    46           2           0.02
# 8     48           3           0.03
# 20    49           2           0.02
# 26    50           2           0.02
# 42    51           1           0.01
# 6     52           3           0.03
# 21    53           2           0.02
# 43    54           1           0.01
# 47    55           1           0.01
# 23    57           2           0.02
# 15    58           2           0.02
# 11    59           3           0.03
# 16    60           2           0.02
# 32    61           1           0.01
# 45    62           1           0.01
# 46    63           1           0.01
# 0     64           6           0.06
# 27    65           2           0.02
# 28    66           2           0.02
# 2     67           4           0.04
# 9     68           3           0.03

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 14    18           2           0.02              2.0
# 7     19           3           0.03              3.0
# 13    20           2           0.02              2.0
# 17    21           2           0.02              2.0
# 34    22           1           0.01              1.0
# 33    23           1           0.01              1.0
# 22    24           2           0.02              2.0
# 36    25           1           0.01              1.0
# 39    26           1           0.01              1.0
# 18    27           2           0.02              2.0
# 41    28           1           0.01              1.0
# 31    29           1           0.01              1.0
# 37    30           1           0.01              1.0
# 44    31           1           0.01              1.0
# 25    32           2           0.02              2.0
# 19    33           2           0.02              2.0
# 3     34           4           0.04              4.0
# 5     35           4           0.04              4.0
# 24    36           2           0.02              2.0
# 35    37           1           0.01              1.0
# 1     38           4           0.04              4.0
# 30    40           2           0.02              2.0
# 40    41           1           0.01              1.0
# 38    42           1           0.01              1.0
# 10    43           3           0.03              3.0
# 4     44           4           0.04              4.0
# 12    45           3           0.03              3.0
# 29    46           2           0.02              2.0
# 8     48           3           0.03              3.0
# 20    49           2           0.02              2.0
# 26    50           2           0.02              2.0
# 42    51           1           0.01              1.0
# 6     52           3           0.03              3.0
# 21    53           2           0.02              2.0
# 43    54           1           0.01              1.0
# 47    55           1           0.01              1.0
# 23    57           2           0.02              2.0
# 15    58           2           0.02              2.0
# 11    59           3           0.03              3.0
# 16    60           2           0.02              2.0
# 32    61           1           0.01              1.0
# 45    62           1           0.01              1.0
# 46    63           1           0.01              1.0
# 0     64           6           0.06              6.0
# 27    65           2           0.02              2.0
# 28    66           2           0.02              2.0
# 2     67           4           0.04              4.0
# 9     68           3           0.03              3.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 14    18           2           0.02              2.0               2
# 7     19           3           0.03              3.0               5
# 13    20           2           0.02              2.0               7
# 17    21           2           0.02              2.0               9
# 34    22           1           0.01              1.0              10
# 33    23           1           0.01              1.0              11
# 22    24           2           0.02              2.0              13
# 36    25           1           0.01              1.0              14
# 39    26           1           0.01              1.0              15
# 18    27           2           0.02              2.0              17
# 41    28           1           0.01              1.0              18
# 31    29           1           0.01              1.0              19
# 37    30           1           0.01              1.0              20
# 44    31           1           0.01              1.0              21
# 25    32           2           0.02              2.0              23
# 19    33           2           0.02              2.0              25
# 3     34           4           0.04              4.0              29
# 5     35           4           0.04              4.0              33
# 24    36           2           0.02              2.0              35
# 35    37           1           0.01              1.0              36
# 1     38           4           0.04              4.0              40
# 30    40           2           0.02              2.0              42
# 40    41           1           0.01              1.0              43
# 38    42           1           0.01              1.0              44
# 10    43           3           0.03              3.0              47
# 4     44           4           0.04              4.0              51
# 12    45           3           0.03              3.0              54
# 29    46           2           0.02              2.0              56
# 8     48           3           0.03              3.0              59
# 20    49           2           0.02              2.0              61
# 26    50           2           0.02              2.0              63
# 42    51           1           0.01              1.0              64
# 6     52           3           0.03              3.0              67
# 21    53           2           0.02              2.0              69
# 43    54           1           0.01              1.0              70
# 47    55           1           0.01              1.0              71
# 23    57           2           0.02              2.0              73
# 15    58           2           0.02              2.0              75
# 11    59           3           0.03              3.0              78
# 16    60           2           0.02              2.0              80
# 32    61           1           0.01              1.0              81
# 45    62           1           0.01              1.0              82
# 46    63           1           0.01              1.0              83
# 0     64           6           0.06              6.0              89
# 27    65           2           0.02              2.0              91
# 28    66           2           0.02              2.0              93
# 2     67           4           0.04              4.0              97
# 9     68           3           0.03              3.0             100

# %% [markdown]
# ---

# %% [markdown]
# ## Regla de sturges
# 1. Es una regla que sirve para calcular el número de clases o intervalos idóneos en los que que se debe dividir un conjunto de datos.
# 2.Establece que **el número de clases es igual a uno más el logaritmo en base dos del número total de datos.**
#
# ** * C= 1 + log²(N)* **
#
# Donde *N* es el tamaño de la muestra.

# %%
import math

# %%
# Volvemos a usar la lista de edades
print (edades)
# Out:
# [59, 24, 67, 67, 42, 45, 41, 34, 64, 33, 35, 64, 62, 52, 20, 27, 40, 46, 64, 63, 65, 50, 35, 32, 36, 57, 43, 18, 38, 33, 18, 49, 31, 54, 45, 38, 40, 59, 43, 44, 51, 64, 52, 30, 50, 34, 28, 68, 26, 58, 68, 34, 48, 43, 19, 53, 19, 27, 35, 67, 48, 34, 44, 44, 25, 24, 45, 60, 21, 49, 37, 22, 23, 61, 58, 65, 29, 67, 68, 53, 66, 59, 66, 32, 38, 36, 19, 21, 38, 48, 55, 64, 35, 60, 44, 52, 57, 46, 20, 64]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     59
# 1     24
# 2     67
# 3     67
# 4     42
# ..   ...
# 95    52
# 96    57
# 97    46
# 98    20
# 99    64
#
# [100 rows x 1 columns]

# %%
# Calcular el número de intervalos utilizando la regla de Sturges
n = len(edades)
k = int( 1 + math.log2(100))
print("Valor de n = ", n , " \nNúmero de intervalos =", k)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
# Crear la tabla de frecuencias

tabla_frecuencia = pd.cut( df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#                           Clase  Frec
# 0                (60.857, 68.0]    20
# 1              (32.286, 39.429]    17
# 2              (39.429, 46.571]    16
# 3  (17.948999999999998, 25.143]    14
# 4              (46.571, 53.714]    13
# 5              (53.714, 60.857]    11
# 6              (25.143, 32.286]     9

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#                           Clase  Frec
# 3  (17.948999999999998, 25.143]    14
# 6              (25.143, 32.286]     9
# 1              (32.286, 39.429]    17
# 2              (39.429, 46.571]    16
# 4              (46.571, 53.714]    13
# 5              (53.714, 60.857]    11
# 0                (60.857, 68.0]    20

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#                           Clase  Frec  Frec Rel  Frec Porc  Frec Ac  \
# 3  (17.948999999999998, 25.143]    14      0.14       14.0       14
# 6              (25.143, 32.286]     9      0.09        9.0       23
# 1              (32.286, 39.429]    17      0.17       17.0       40
# 2              (39.429, 46.571]    16      0.16       16.0       56
# 4              (46.571, 53.714]    13      0.13       13.0       69
# 5              (53.714, 60.857]    11      0.11       11.0       80
# 0                (60.857, 68.0]    20      0.20       20.0      100
#
#    Frec Rel Ac  Frec Porc Ac
# 3         0.14          14.0
# 6         0.23          23.0
# 1         0.40          40.0
# 2         0.56          56.0
# 4         0.69          69.0
# 5         0.80          80.0
# 0         1.00         100.0

# %%
import matplotlib.pyplot as plt # Importing the matplotlib.pyplot module and assigning it to the alias 'plt'

plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estándar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estándar')

# %%
# Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=k, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# ---

# %% [markdown]
# #   **Práctica #5** *Diagramas de Cajas y bigotes.*

# %%
edades2= []

# Hacemos un ciclo para generar 100 números aleatorios que representan la edad de las personas
for i in range(100):
    # generamos un número aleatorio con la funcion randint y lo guardamos en la variable
    # numero_aleatorio
    numero_aleatorio = random.randint( 20, 87)
    # Agregamos el número aleatorio a la lista de valores
    edades2.append(numero_aleatorio)

print(edades2)
# Out:
# [29, 83, 72, 41, 21, 43, 42, 37, 77, 67, 61, 84, 20, 31, 62, 54, 76, 35, 27, 27, 61, 58, 31, 25, 37, 34, 58, 79, 37, 64, 41, 50, 85, 59, 53, 38, 70, 47, 86, 54, 83, 76, 30, 77, 51, 68, 23, 38, 67, 38, 52, 80, 76, 63, 74, 42, 49, 74, 33, 74, 83, 69, 31, 60, 39, 68, 58, 46, 22, 73, 81, 53, 72, 40, 65, 50, 28, 37, 63, 43, 21, 51, 59, 39, 75, 34, 36, 69, 26, 55, 55, 85, 36, 31, 53, 61, 21, 56, 57, 74]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

bplot1 = ax1.boxplot(edades,
                     vert=True, # vertical box alignment
                     patch_artist=True) #fill with color
ax1.set_title('Edades Encuenta 1')

bplot2 = ax2.boxplot(edades2,
                     vert=True, # vertical box alignment
                     patch_artist=True) #fill with color
ax2.set_title('Edades Encuenta 2')
plt.show()

# %%
edades2.append(130)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

bplot1 = ax1.boxplot(edades,
                     vert=True, # vertical box alignment
                     patch_artist=True) #fill with color
ax1.set_title('Edades Encuenta 1')

bplot2 = ax2.boxplot(edades2,
                     vert=True, # vertical box alignment
                     patch_artist=True) #fill with color
ax2.set_title('Edades Encuenta 2')
plt.show()
